# %% [markdown]
# ###  A

# %%
N, M = map(int, input().split())
print("Yes" if N ==M else "No")
# Out:
# 1 2
# False

# %% [markdown]
# ### B

# %%
a, b = map(str, input().split())
a_list =[]
b_list =[]

for i in range(int(b)):
   a_list.append(a)

for i in range(int(a)):
   b_list.append(b)    

map_result = map(str, a_list)
result_a = ''.join(map_result)
map_result = map(str, b_list)
result_b = ''.join(map_result)

sorted_list = sorted([result_a,result_b])
print(sorted_list[0])
# Out:
# 3 3
# 333

# %% [markdown]
# ### C

# %%
input_N = int(input())
p_list = list(map(int, input().split()))
# Out:
# 8
# 5 7 4 2 6 8 1 3

# %%
cnt =1
for i in range(input_N-1):
    if p_list[i] > p_list[i+1]:
        cnt += 1
    else:
#         print(i)

        p_list[i+1] = p_list[i]
        
print(cnt)
# Out:
# 4

# %% [markdown]
# ### D

# %%
import numpy as np
import sys

# input_N = sys.stdin.readline
# input_N=sys.stdin.readline().strip()
input_N = int(input())
cnt=0

for i in range(1,input_N):
    string = str(i)
    if string[-1] == string[0] :
        reverse_string = string[0] 
        if int(reverse_string) <= input_N:
            print(i,reverse_string)  
            cnt +=1

    reverse_string = string[-1] + string[0] 
    if int(reverse_string) <= input_N and int(reverse_string[0]) != 0:
        print(i,reverse_string)
        cnt +=1
    
    for j in range(0,int(input_N)):
        reverse_string = string[-1] + str(j) +  string[0] 
        if int(reverse_string) <= input_N and int(reverse_string[0]) != 0:
#             print(i,reverse_string)  
            cnt +=1
        
print(cnt)
# Out:
# 2000
# 1 1
# 1 11
# 2 2
# 2 22
# 3 3
# 3 33
# 4 4
# 4 44
# 5 5
# 5 55
# 6 6
# 6 66
# 7 7
# 7 77
# 8 8
# 8 88
# 9 9
# 9 99
# 11 1
# 11 11
# 12 21
# 13 31
# 14 41
# 15 51
# 16 61
# 17 71
# 18 81
# 19 91
# 21 12
# 22 2
# 22 22
# 23 32
# 24 42
# 25 52
# 26 62
# 27 72
# 28 82
# 29 92
# 31 13
# 32 23
# 33 3
# 33 33
# 34 43
# 35 53
# 36 63
# 37 73
# 38 83
# 39 93
# 41 14
# 42 24
# 43 34
# 44 4
# 44 44
# 45 54
# 46 64
# 47 74
# 48 84
# 49 94
# 51 15
# 52 25
# 53 35
# 54 45
# 55 5
# 55 55
# 56 65
# 57 75
# 58 85
# 59 95
# 61 16
# 62 26
# 63 36
# 64 46
# 65 56
# 66 6
# 66 66
# 67 76
# 68 86
# 69 96
# 71 17
# 72 27
# 73 37
# 74 47
# 75 57
# 76 67
# 77 7
# 77 77
# 78 87
# 79 97
# 81 18
# 82 28
# 83 38
# 84 48
# 85 58
# 86 68
# 87 78
# 88 8
# 88 88
# 89 98
# 91 19
# 92 29
# 93 39
# 94 49
# 95 59
# 96 69
# 97 79
# 98 89
# 99 9
# 99 99
# 101 1
# 101 11
# 102 21
# 103 31
# 104 41
# 105 51
# 106 61
# 107 71
# 108 81
# 109 91
# 111 1
# 111 11
# 112 21
# 113 31
# 114 41
# 115 51
# 116 61
# 117 71
# ...
